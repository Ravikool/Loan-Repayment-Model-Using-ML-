# %% [markdown]
# #### Machine Learning Project Module
# #### Domain : Banking
# #### Dataset : Loan Payments
#
# #### Objective : In the Loan Payment dataset, We would like to perform classification on Loan_status variable that contains three categories namely PAIDOFF,COLLETION AND COLLECTION_PAIDOFF.
#
# #### Solution : This analysis will generate valuable insights for banks to consider which customers they will provide loan to.
# #### Approach: We will try 3 to 4 algorithms and display results
#
# #### Plan: Start with EDA and Visualisations

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

import matplotlib.pyplot as plt
import seaborn as sns # Visualizations tools
# %matplotlib inline

import pandas_profiling  #Data insights 

import warnings
warnings.filterwarnings("ignore")

# %%
loan_payment = pd.read_csv("C:/Users/RAVI/Favorites/Downloads/UPX Material/Machine Learning/Project datasets/Loan Payment/Loan payments data.csv")

# %% [markdown]
# #### 1. EDA  : In this section, let's explore the data in-depth.

# %%
loan_payment.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date    due_date  \
# 0  xqd20166231     PAIDOFF       1000     30     09/08/2016  10/07/2016
# 1  xqd20168902     PAIDOFF       1000     30     09/08/2016  10/07/2016
# 2  xqd20160003     PAIDOFF       1000     30     09/08/2016  10/07/2016
# 3  xqd20160004     PAIDOFF       1000     15     09/08/2016   9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30     09/09/2016  10/08/2016
#
#       paid_off_time  past_due_days  age             education  Gender
# 0   9/14/2016 19:31            NaN   45  High School or Below    male
# 1  10/07/2016 09:00            NaN   50              Bachelor  female
# 2   9/25/2016 16:58            NaN   33              Bachelor  female
# 3   9/22/2016 20:00            NaN   27               college    male
# 4   9/23/2016 21:36            NaN   28               college  female

# %% [markdown]
# Comment: OK from the sample, we can see that it's making senses for those who have paid the loan off to not have data in past_due_days columns.

# %% [markdown]
# #### 2. loan_status : This field is actually the target variables we are trying to predict. Let's look at the LoV within the column and the sizing.

# %%
loan_payment['loan_status'].unique()
# Out:
# array(['PAIDOFF', 'COLLECTION', 'COLLECTION_PAIDOFF'], dtype=object)

# %% [markdown]
# Comment: We have 3 labels for this target variables with the ratio of 3:1:1 (paid off: collection : collection paid off).

# %%
pandas_profiling.ProfileReport(loan_payment)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>11 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>500 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>7.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>29.3 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>60.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_paid_off_time"><code>paid_off_time</code></a> has 100 / 20.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_paid_off_time"><code>paid_off_time</code></a> has a high cardinality: 321 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_past_due_days"><code>past_due_days</code></a> has 300 / 60.0% missing values <span class="label label-default">Missing</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Gender">Gender<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="">
#             <th>Distinct count</th>
#             <td>2</td>
#         </tr>
#         <tr>
#             <th>Unique (%)</th>
#             <td>0.4%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (%)</th>
#             <td>0.0%</td>
#         </tr>
#         <tr class="ignore">
#             <th>Missing (n)</th>
#             <td>0</td>
#         </tr>
#     </table>
# </div>
# <div class="col-md-

# %%
loan_payment.groupby('loan_status')['Gender'].agg(['count'])
# Out:
#                     count
# loan_status
# COLLECTION            100
# COLLECTION_PAIDOFF    100
# PAIDOFF               300

# %%
print(loan_payment.loan_status.unique())

fig = plt.figure(figsize=(5,5))
ax = sns.countplot(loan_payment.loan_status)
ax.set_title("Count of Loan Status")
for p in ax.patches:
    ax.annotate(str(format(int(p.get_height()), ',d')), (p.get_x(), p.get_height()*1.01))
plt.show()
# Out:
# ['PAIDOFF' 'COLLECTION' 'COLLECTION_PAIDOFF']

# %% [markdown]
# #### 3. Principal : This is the loan amount at the origination.

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))
sns.boxplot(x='loan_status', y='Principal', data=loan_payment, hue='loan_status', ax=axs[0])
sns.distplot(loan_payment.Principal, bins=range(300, 1000, 100), ax=axs[1], kde=True)
plt.show();

# %% [markdown]
# Comment :Based on the distribution alone, majority of the principal is 1,000 (USD??). Below aggregation shows more detail of the Principal with loan_status.

# %%
print(loan_payment[['loan_status', 'Principal', 'Loan_ID']].groupby(['loan_status', 'Principal']).agg(['count']))
# Out:
#                              Loan_ID
#                                count
# loan_status        Principal
# COLLECTION         800            23
#                    1000           77
# COLLECTION_PAIDOFF 500             1
#                    800            19
#                    1000           80
# PAIDOFF            300             6
#                    500             2
#                    700             1
#                    800            69
#                    900             2
#                    1000          220

# %% [markdown]
# #### 4. Terms :This is the payoff schedule, which can be in week, month etc.

# %%
fig, axs = plt.subplots(1, 2, figsize=(16,5))
sns.countplot(loan_payment.terms, ax=axs[0])
axs[0].set_title("Count of Terms of loan")
for p in axs[0].patches:
    axs[0].annotate(str(format(int(p.get_height()), ',d')), (p.get_x(), p.get_height()*1.01))

sns.countplot(x='terms', hue='loan_status', data=loan_payment, ax=axs[1])
axs[1].set_title("Term count breakdown by loan_status")
for t in axs[1].patches:
    if (np.isnan(float(t.get_height()))):
        axs[1].annotate(0, (t.get_x(), 0))
    else:
        axs[1].annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

axs[1].legend(loc='upper left')
plt.show();

# %% [markdown]
# Comment: 5, 6, 7, 8. effective_date, due_date, paid_off_time, and past_due_days
# These data points are essentially related to the date of the loan and payment.

# %%
fig = plt.figure(figsize=(10,5))
ax = sns.countplot(x='effective_date', hue='loan_status', data=loan_payment)
ax.set_title('Loan date')
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))
plt.show();

# Note: if we think that the day of week, or month has the significant factor to the loan status
# Below is the function which we can use to extract the year, month, or day:
# pd.DatetimeIndex(loan_data.effective_date).year
# pd.DatetimeIndex(loan_data.effective_date).month
# pd.DatetimeIndex(loan_data.effective_date).day

# %% [markdown]
# Comment: It looks like this is snapshot of the 7-day loan data, with 11-September has the most loan.
#
# In the next figure, is there any pattern of the pay off date? In this section, we add new column paid_off_date from the paid_off_time.

# %%
loan_payment['paid_off_date'] = pd.DatetimeIndex(loan_payment.paid_off_time).normalize()
fig = plt.figure(figsize=(16, 6))
ax = sns.countplot(x='paid_off_date', data=loan_payment.loc[loan_payment.loan_status.isin(['COLLECTION_PAIDOFF', 'PAIDOFF'])] , hue='loan_status')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

ax.legend(loc='upper right')
plt.show();

# %% [markdown]
# Comment: As expected, people are more likely to pay off the loan on the last day. Big spike on day 14 and day 29 for 15-day and 30-day terms, respectively.

# %%
# Compute the day to pay-off the loan
loan_payment['day_to_pay'] = (pd.DatetimeIndex(loan_payment.paid_off_time).normalize() - pd.DatetimeIndex(loan_payment.effective_date).normalize()) / np.timedelta64(1, 'D')

fig = plt.figure(figsize=(15, 5))
ax = sns.countplot(x='day_to_pay', hue='terms', data=loan_payment)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate('', (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))
        
plt.show();

# %% [markdown]
# Comment: Let's see the distribution of PAIDOFF, what days do they normally pay off the loan?

# %%
fig = plt.figure(figsize=(15, 5))
ax = sns.countplot(x='day_to_pay', hue='terms', data=loan_payment.loc[loan_payment.loan_status == 'PAIDOFF'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate('', (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))
        
plt.show();

# %%
fig, axs = plt.subplots(3, 2, figsize=(16, 15))
sns.distplot(loan_payment.age, ax=axs[0][0])
axs[0][0].set_title("Total age distribution across dataset")
sns.boxplot(x='loan_status', y='age', data=loan_payment, ax=axs[0][1])
axs[0][1].set_title("Age distribution by loan status")
sns.countplot(x='education', data=loan_payment, ax=axs[1][0])
axs[1][0].set_title("Education count")
for t in axs[1][0].patches:
    if (np.isnan(float(t.get_height()))):
        axs[1][0].annotate('', (t.get_x(), 0))
    else:
        axs[1][0].annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

sns.countplot(x='education', data=loan_payment, hue='loan_status', ax=axs[1][1])
axs[1][1].set_title("Education by loan status")
for t in axs[1][1].patches:
    if (np.isnan(float(t.get_height()))):
        axs[1][1].annotate('', (t.get_x(), 0))
    else:
        axs[1][1].annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

axs[1][1].legend(loc='upper right')
sns.countplot(x='Gender', data=loan_payment, ax=axs[2][0])
axs[2][0].set_title("# of Gender")
for t in axs[2][0].patches:
    if (np.isnan(float(t.get_height()))):
        axs[2][0].annotate('', (t.get_x(), 0))
    else:
        axs[2][0].annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

sns.countplot(x='Gender', data=loan_payment, hue='education', ax=axs[2][1])
axs[2][1].set_title("Education of the gender")
for t in axs[2][1].patches:
    if (np.isnan(float(t.get_height()))):
        axs[2][1].annotate('', (t.get_x(), 0))
    else:
        axs[2][1].annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))

plt.show();

# %%
# Quick view on education + gender => impact to loan_status
pd.crosstab(loan_payment.loan_status, loan_payment.Gender + "_" + loan_payment.education, margins=True)
# Out:
# col_0               female_Bachelor  female_High School or Below  \
# loan_status
# COLLECTION                        0                            7
# COLLECTION_PAIDOFF                1                            5
# PAIDOFF                          12                           19
# All                              13                           31
#
# col_0               female_college  male_Bachelor  male_High School or Below  \
# loan_status
# COLLECTION                       3             11                         42
# COLLECTION_PAIDOFF               8             14                         32
# PAIDOFF                         22             29                        104
# All                             33             54                        178
#
# col_0               male_Master or Above  male_college  All
# loan_status
# COLLECTION                             1            36  100
# COLLECTION_PAIDOFF                     0            40  100
# PAIDOFF                                3           111  300
# All                                    4           187  500

# %% [markdown]
# 9, 10, 11. age, education, and gender
# These data points are the demographic information of the applicant.

# %%
pd.crosstab(loan_payment.loan_status, loan_payment.Gender + "_" + loan_payment.education, margins=True, normalize='columns')
# Out:
# col_0               female_Bachelor  female_High School or Below  \
# loan_status
# COLLECTION                 0.000000                     0.225806
# COLLECTION_PAIDOFF         0.076923                     0.161290
# PAIDOFF                    0.923077                     0.612903
#
# col_0               female_college  male_Bachelor  male_High School or Below  \
# loan_status
# COLLECTION                0.090909       0.203704                   0.235955
# COLLECTION_PAIDOFF        0.242424       0.259259                   0.179775
# PAIDOFF                   0.666667       0.537037                   0.584270
#
# col_0               male_Master or Above  male_college  All
# loan_status
# COLLECTION                          0.25      0.192513  0.2
# COLLECTION_PAIDOFF                  0.00      0.213904  0.2
# PAIDOFF                             0.75      0.593583  0.6

# %%
loan_payment1=loan_payment.copy()

# %% [markdown]
# 2.Classification Model
# My aim of this model is to classify the one who will likely to pay the loan off on time. We will assume those who are in COLLECTION or COLLECTION_PAIDOFF the same, hence don't pay on the loan due date. This will provide the basic step, no tu
#
# First, let's prepare the data for model building purpose.
#
# As per the above EDA, we will fix those mislead status loan records.
#
# Great, now let's change the categorical target variables to numeric one. As per stated earlier, I will merge COLLECTION and COLLECTION_PAIDOFF to the same category, hence didn't pay on-time.
#
# NOTE: This will depends on each individual objective, some model will interest on any loan paidoff without consideration of on-time or delay.

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
loan_payment['loan_status']=le.fit_transform(loan_payment['loan_status'])
loan_payment['Gender']=le.fit_transform(loan_payment['Gender'])
loan_payment['education']=le.fit_transform(loan_payment['education'])
loan_payment['past_due_days']=le.fit_transform(loan_payment['past_due_days'])

# %%
loan_payment1.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date    due_date  \
# 0  xqd20166231     PAIDOFF       1000     30     09/08/2016  10/07/2016
# 1  xqd20168902     PAIDOFF       1000     30     09/08/2016  10/07/2016
# 2  xqd20160003     PAIDOFF       1000     30     09/08/2016  10/07/2016
# 3  xqd20160004     PAIDOFF       1000     15     09/08/2016   9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30     09/09/2016  10/08/2016
#
#       paid_off_time  past_due_days  age             education  Gender
# 0   9/14/2016 19:31            NaN   45  High School or Below    male
# 1  10/07/2016 09:00            NaN   50              Bachelor  female
# 2   9/25/2016 16:58            NaN   33              Bachelor  female
# 3   9/22/2016 20:00            NaN   27               college    male
# 4   9/23/2016 21:36            NaN   28               college  female

# %%
dataf =loan_payment1[loan_payment['past_due_days'] ==60 ]
dataf.head(5)
# Out:
#          Loan_ID loan_status  Principal  terms effective_date    due_date  \
# 299  xqd20160300     PAIDOFF       1000     30      9/14/2016  10/13/2016
#
#         paid_off_time  past_due_days  age education Gender
# 299  10/13/2016 11:00            NaN   28   college   male

# %%
loan_payment1.groupby('loan_status')['Gender'].agg(['count'])
# Out:
#                     count
# loan_status
# COLLECTION            100
# COLLECTION_PAIDOFF    100
# PAIDOFF               300

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
loan_payment['loan_status']=le.fit_transform(loan_payment['loan_status'])
loan_payment['Gender']=le.fit_transform(loan_payment['Gender'])
loan_payment['education']=le.fit_transform(loan_payment['education'])
loan_payment['past_due_days']=le.fit_transform(loan_payment['past_due_days'])

# %%
loan_payment1=loan_payment
loan_payment1.drop('Loan_ID', axis=1, inplace=True)
label = loan_payment1.pop('loan_status')

# %%
loan_payment1.drop('effective_date', axis=1, inplace=True)
loan_payment1.drop('due_date', axis=1, inplace=True)
loan_payment1.drop('paid_off_time', axis=1, inplace=True)

# %%
loan_payment.head()
# Out:
#    Principal  terms  past_due_days  age  education  Gender
# 0       1000     30             83   45          1       1
# 1       1000     30            173   50          0       0
# 2       1000     30            172   33          0       0
# 3       1000     15            171   27          3       1
# 4       1000     30            170   28          3       0

# %%
loan_payment1.head()
# Out:
#    Principal  terms  past_due_days  age  education  Gender
# 0       1000     30             83   45          1       1
# 1       1000     30            173   50          0       0
# 2       1000     30            172   33          0       0
# 3       1000     15            171   27          3       1
# 4       1000     30            170   28          3       0

# %%
#Train-Test split
from sklearn.model_selection import train_test_split
data_train, data_test, label_train, label_test = train_test_split(loan_payment1, label, test_size = 0.2, random_state = 42)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
logis = LogisticRegression()
logis.fit(data_train, label_train)

logis_score_train = logis.score(data_train, label_train)
print("Training score: ",logis_score_train)

logis_score_test = logis.score(data_test, label_test)
print("Testing score: ",logis_score_test)
# Out:
# Training score:  0.9625
# Testing score:  0.97

# %%
# Decision tree
from sklearn import tree
dt = tree.DecisionTreeClassifier()
dt.fit(data_train, label_train)
dt_score_train = dt.score(data_train, label_train)
print("Training score: ",dt_score_train)
dt_score_test = dt.score(data_test, label_test)
print("Testing score: ",dt_score_test)
# Out:
# Training score:  1.0
# Testing score:  0.97

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
dt = RandomForestClassifier()
dt.fit(data_train, label_train)
dt_score_train = dt.score(data_train, label_train)
print("Training score: ",dt_score_train)
dt_score_test = dt.score(data_test, label_test)
print("Testing score: ",dt_score_test)
# Out:
# Training score:  1.0
# Testing score:  0.96

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(data_train, label_train)
rfc_score_train = rfc.score(data_train, label_train)
print("Training score: ",rfc_score_train)
rfc_score_test = rfc.score(data_test, label_test)
print("Testing score: ",rfc_score_test)
# Out:
# Training score:  0.995
# Testing score:  0.96

# %%
#Model comparison
models = pd.DataFrame({
        'Model'          : ['Logistic Regression',  'Decision Tree', 'Random Forest'],
        'Training_Score' : [logis_score_train,  dt_score_train, rfc_score_train],
        'Testing_Score'  : [logis_score_test, dt_score_test, rfc_score_test]
    })
models.sort_values(by='Testing_Score', ascending=False)
# Out:
#                  Model  Training_Score  Testing_Score
# 0  Logistic Regression          0.9625           0.97
# 1        Decision Tree          1.0000           0.96
# 2        Random Forest          0.9950           0.96

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.svm import SVC,LinearSVC
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
lrr=LogisticRegression()
lrr.fit(data_train, label_train)

label_test=lrr.predict(data_test)

print("Logistic Regression Test Accuracy :{:2f}".format(round(lrr.score(data_test, label_test)*100,2)))
print("Logistic Regression Train Accuracy :{:2f}".format(round(lrr.score(data_train, label_train)*100,2)))
# Out:
# Logistic Regression Test Accuracy :100.000000
# Logistic Regression Train Accuracy :96.250000

# %%
lr=LinearRegression(n_jobs=3)
lr.fit(data_train, label_train)

label_test=lr.predict(data_test).astype(int)


print("LinearRegression Test Accuracy :{:2f}".format(round(lr.score(data_test,label_test)*100,2)))
print("LinearRegressionTrain Accuracy :{:2f}".format(round(lr.score(data_train,label_train)*100,2)))
# Out:
# LinearRegression Test Accuracy :-7.180000
# LinearRegressionTrain Accuracy :46.850000

# %%
svc=SVC(random_state=0,kernel='rbf')
svc.fit(data_train,label_train)

label_test=lr.predict(data_test).astype(int)


print("SVC Test Accuracy :{:2f}".format(round(svc.score(data_test,label_test)*100,2)))
print("SVC Train Accuracy :{:2f}".format(round(svc.score(data_train,label_train)*100,2)))
# Out:
# SVC Test Accuracy :29.000000
# SVC Train Accuracy :100.000000

# %%
lsvc=LinearSVC(random_state=0)
lsvc.fit(data_train,label_train)

label_test=lsvc.predict(data_test).astype(int)


print("LinearSVC Test Accuracy :{:2f}".format(round(lsvc.score(data_test,label_test)*100,2)))
print("LinearSVC Train Accuracy :{:2f}".format(round(lsvc.score(data_train,label_train)*100,2)))
# Out:
# LinearSVC Test Accuracy :100.000000
# LinearSVC Train Accuracy :80.500000
